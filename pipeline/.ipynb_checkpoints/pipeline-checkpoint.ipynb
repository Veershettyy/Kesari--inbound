# %% [markdown]
# # KESARi Inbound — Auto Translation Pipeline
#
# This notebook does everything automatically:
#
# | Step | What happens |
# |------|-------------|
# | 1 | Install dependencies |
# | 2 | Render all React pages using a headless browser → save to `INT/ENG/` |
# | 3 | Detect which pages changed (SHA-256 comparison) |
# | 4 | Translate only changed pages → save to `INT/es/`, `INT/fr/`, etc. |
# | 5 | Rewrite internal links in translated files |
# | 6 | Schedule to run automatically every 24 hours |
#
# ---
# **Before running:**
# - Make sure `npm run dev` is running in a separate terminal
# - Make sure `pipeline/.env` has `MISTRAL_API_KEY=your_key`

# %% [markdown]
# ## Step 1 — Install Dependencies
# Run this cell only once.

# %%
import subprocess, sys

print('Installing Python packages...')
subprocess.check_call([sys.executable, '-m', 'pip', 'install', '-q',
    'playwright', 'beautifulsoup4', 'lxml', 'mistralai', 'python-dotenv', 'schedule'])

print('Installing Playwright browser...')
subprocess.check_call([sys.executable, '-m', 'playwright', 'install', 'chromium'])

print('✔ All dependencies ready')

# %% [markdown]
# ## Step 2 — Check Configuration

# %%
import os, sys
sys.path.insert(0, os.path.dirname(os.path.abspath('__file__')))

from dotenv import load_dotenv
load_dotenv('.env')

from config import DEV_SERVER_URL, ENG_DIR, INT_DIR, LANGUAGES, ALL_ROUTES, CHECK_INTERVAL_HOURS

print(f'Dev server URL  : {DEV_SERVER_URL}')
print(f'English folder  : {ENG_DIR}')
print(f'Output folder   : {INT_DIR}')
print(f'Languages       : {list(LANGUAGES.keys())}')
print(f'Pages to scrape : {len(ALL_ROUTES)}')
print(f'Check every     : {CHECK_INTERVAL_HOURS} hours')
print()

if not os.environ.get('MISTRAL_API_KEY'):
    print('⚠️  MISTRAL_API_KEY not set! Add it to pipeline/.env')
else:
    print('✔ MISTRAL_API_KEY loaded')

# %% [markdown]
# ## Step 3 — Scrape: Render React App Pages → Save to INT/ENG/
#
# ⚠️ Make sure `npm run dev` is running first!
#
# This uses a **headless Chromium browser** to fully render each React route,
# then saves the complete HTML (with all content visible) to `INT/ENG/`.

# %%
from scraper import scrape

print(f'Starting scrape of {DEV_SERVER_URL}...\n')
changed_pages = scrape(verbose=True)

print(f'\n── Result ──')
print(f'{len(changed_pages)} page(s) changed / new')
for route, path in changed_pages:
    print(f'  {route}')

# %% [markdown]
# ## Step 4 — Translate Changed Pages → All Language Folders
#
# Only pages that changed in Step 3 are translated.
# If nothing changed, this step is skipped automatically.

# %%
from translator import translate_changed_pages

if not changed_pages:
    print('No pages changed — nothing to translate. ✔')
else:
    print(f'Translating {len(changed_pages)} page(s) into {len(LANGUAGES)} languages...\n')
    translate_changed_pages(changed_pages)
    print('\n✔ Translation complete!')

# %% [markdown]
# ## Step 5 — Verify Output Structure

# %%
import glob

print('INT/ folder structure:\n')
for lang in ['ENG'] + list(LANGUAGES.keys()):
    folder = os.path.join(INT_DIR, lang)
    files  = glob.glob(os.path.join(folder, '**', '*.html'), recursive=True)
    status = '✔' if files else '⚠️ empty'
    print(f'  {status}  INT/{lang}/  →  {len(files)} HTML files')

# %% [markdown]
# ## Step 6 (Optional) — Force Translate ALL Pages from Scratch
#
# Use this only on the **first run** or when you add a new language.
# Translates every file in `INT/ENG/` regardless of change detection.

# %%
# Uncomment the lines below and run this cell to force translate everything

# from translator import translate_all_pages
# translate_all_pages()

# %% [markdown]
# ## Step 7 — Auto Scheduler (Runs Every 24 Hours)
#
# Keep this cell running to automatically check for changes and translate every day.
#
# **How it works:**
# - Every 24 hours it scrapes the site
# - If any page changed → translates only that page
# - If nothing changed → prints 'No changes' and waits again
#
# You can change `CHECK_INTERVAL_HOURS` in `config.py`.

# %%
import schedule, time, datetime
from scraper import scrape
from translator import translate_changed_pages
from config import CHECK_INTERVAL_HOURS, LANGUAGES

def run_pipeline():
    now = datetime.datetime.now().strftime('%Y-%m-%d %H:%M')
    print(f'\n[{now}] ▶ Running pipeline...')
    
    changed = scrape(verbose=False)
    
    if changed:
        print(f'  {len(changed)} page(s) changed — translating into {len(LANGUAGES)} languages...')
        translate_changed_pages(changed)
        print(f'  ✔ Done! Next check in {CHECK_INTERVAL_HOURS}h')
    else:
        print(f'  No changes detected. Next check in {CHECK_INTERVAL_HOURS}h')

# Schedule to run every 24 hours
schedule.every(CHECK_INTERVAL_HOURS).hours.do(run_pipeline)

print(f'✔ Scheduler started — pipeline will run every {CHECK_INTERVAL_HOURS} hours')
print(f'  Next run at: {(datetime.datetime.now() + datetime.timedelta(hours=CHECK_INTERVAL_HOURS)).strftime("%Y-%m-%d %H:%M")}')
print('  (Keep this cell running. Press ■ Stop to cancel)\n')

# Run once immediately, then on schedule
run_pipeline()

while True:
    schedule.run_pending()
    time.sleep(60)

# %% [markdown]
# ---
# ## Quick Reference
#
# | Task | Which cell to run |
# |------|------------------|
# | First time setup | Step 1 (install) then Step 6 (translate all) |
# | Daily manual run | Step 3 → Step 4 |
# | Auto daily run | Step 7 (keep running) |
# | Check what's done | Step 5 |
# | Add new language | Add to `config.py` LANGUAGES, then run Step 6 |
#
# **Folder structure after pipeline runs:**
# ```
# INT/
#   ENG/                          ← original English (source)
#     index.html
#     explore/index.html
#     destinations/index.html
#     packages/index.html
#     explore/product-details/FIT-INBOUND-01/index.html
#     ... (70 pages total)
#
#   es/                           ← Spanish (auto-translated)
#     index.html
#     explore/index.html
#     ... (same structure)
#
#   fr/ de/ hi/ ja/ pt/ it/ zh/ ar/ ko/ ml/ pl/
#     ... (same structure, 12 languages)
# ```
